# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIRAJAWAT-07/AbhiRajawat-07/blob/main/Column_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('covid_toy.csv')
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)
X_train
# Out:
#     age  gender  fever   cough       city
# 72   83  Female  101.0    Mild    Kolkata
# 25   23    Male    NaN    Mild     Mumbai
# 40   49  Female  102.0    Mild      Delhi
# 16   69  Female  103.0    Mild    Kolkata
# 45   72    Male   99.0    Mild  Bangalore
# ..  ...     ...    ...     ...        ...
# 49   44    Male  104.0    Mild     Mumbai
# 78   11    Male  100.0    Mild  Bangalore
# 99   10  Female   98.0  Strong    Kolkata
# 42   27    Male  100.0    Mild      Delhi
# 39   50  Female  103.0    Mild    Kolkata
#
# [80 rows x 5 columns]

# %%
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])

# also the test data
X_test_fever = si.fit_transform(X_test[['fever']])

X_train_fever.shape
# Out:
# (80, 1)

# %%
oe = OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough = oe.fit_transform(X_train[['cough']])

# also the test data
X_test_cough = oe.fit_transform(X_test[['cough']])

X_train_cough.shape
# Out:
# (80, 1)

# %%
# Out:
# (80, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop='first', sparse_output=False)

# %%
X_train_gender_city = ohe.fit_transform(
    X_train[['gender', 'city']]
)

# %%
X_test_gender_city = ohe.transform(
    X_test[['gender', 'city']]
)

# %%
import numpy as np

X_train_transformed = np.concatenate(
    (X_train_age,
     X_train_fever,
     X_train_gender_city,
     X_train_cough),
    axis=1
)

# %%
X_test_transformed = np.concatenate(
    (X_test_age,
     X_test_fever,
     X_test_gender_city,
     X_test_cough),
    axis=1
)

# %%
ohe = OneHotEncoder(drop='first')
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# (80, 4)

# %%
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

# also the test data
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
# also the test data
X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)

X_train_transformed.shape
# Out:
# (80, 7)

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse=False,drop='first'),['gender','city'])
],remainder='passthrough')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2883790847.py in <cell line: 0>()
#       2     ('tnf1',SimpleImputer(),['fever']),
#       3     ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
# ----> 4     ('tnf3',OneHotEncoder(sparse=False,drop='first'),['gender','city'])
#       5 ],remainder='passthrough')
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
transformer.fit_transform(X_train).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2077289377.py in <cell line: 0>()
# ----> 1 transformer.fit_transform(X_train).shape
#
# NameError: name 'transformer' is not defined

# %%
transformer.transform(X_test).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2918376525.py in <cell line: 0>()
# ----> 1 transformer.transform(X_test).shape
#
# NameError: name 'transformer' is not defined

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer

preprocessor = ColumnTransformer(transformers=[

    ('imputer', SimpleImputer(strategy='most_frequent'), ['fever']),

    ('ordinal', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),

    ('onehot', OneHotEncoder(drop='first', sparse_output=False), ['gender', 'city'])

], remainder='passthrough')

# %%
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# %%
preprocessor.fit_transform(X_train).shape
# Out:
# (80, 7)

# %%
preprocessor.transform(X_test).shape
# Out:
# (20, 7)
